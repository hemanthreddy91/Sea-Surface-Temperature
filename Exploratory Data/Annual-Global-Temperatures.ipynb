# %%
import project59970 as proj
# %matplotlib inline

# %%
global_temperatures = proj.create_dataframe()
global_temperatures.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0 1743-11-01               4.384                          2.294   Åland
# 1 1743-12-01                 NaN                            NaN   Åland
# 2 1744-01-01                 NaN                            NaN   Åland
# 3 1744-02-01                 NaN                            NaN   Åland
# 4 1744-03-01                 NaN                            NaN   Åland

# %%
proj.plot_avg_global_temperatures(global_temperatures, 1755, 2013)

# %% [markdown]
# ### The plot is color-coded to visually show the change in average global temperatures

# %%
proj.plot_uncertainty(global_temperatures, 1755, 2013)

# %% [markdown]
# ### When we overlay the uncertainty with the average global temperatures, we notice the accuracy has improved as we approach more recent years (hence the smaller area of uncertainty).

# %%
proj.plot_avg_seasonal_global_temperatures(global_temperatures, 1755, 2010)

# %% [markdown]
# ### In seperating the data by season, we can observe any seasonal changes that might have occured over a period of time.  Additionally, we can prevent the influence of seasonal changes being a factor when analyzing average temperatures across each year as a whole. (e.g. isolating every summer of each year)
